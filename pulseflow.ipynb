# %%
# !pip install fredapi psycopg2-binary python-dotenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 37.4 MB/s eta 0:00:00
# ...

# %%
import psycopg2
from google.colab import userdata

conn = psycopg2.connect(
    host="db.hinbnwvgdwolvoobrahh.supabase.co",
    port=5432,  # Database 섹션에서 확인
    database="postgres",  # Database 섹션에서 확인
    user="postgres",  # Database 섹션에서 확인
    password=userdata.get('SUPABASE_PASS')  # 프로젝트 생성 시 설정한 비밀번호
)

cur = conn.cursor()
cur.execute("SELECT 1;")
print("✅ 연결 성공!")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipython-input-503376543.py in <cell line: 0>()
#       2 from google.colab import userdata
#       3
# ----> 4 conn = psycopg2.connect(
#       5     host="db.hinbnwvgdwolvoobrahh.supabase.co",
#       6     port=5432,  # Database 섹션에서 확인
#
# /usr/local/lib/python3.12/dist-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "db.hinbnwvgdwolvoobrahh.supabase.co" (2600:1f18:2e13:9d26:4444:6a37:3367:2e0a), port 5432 failed: Network is unreachable
# ...

# %% [markdown]
# #AWS dynamo freeplan
